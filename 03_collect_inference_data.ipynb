# %%
import gc
from concurrent.futures import ThreadPoolExecutor, as_completed
import earthaccess
import joblib
import json
import pandas as pd
import numpy as np
from shapely.geometry import shape
import xarray as xr
from typing import Dict, Any
import fsspec
from pystac_client import Client

import data_classes

# %%
with open('ski_areas.geojson', 'r') as f:
    ski_areas = json.load(f)

# %%
crystal_mountain_area = [site for site in ski_areas['features'] if site['properties']['name'] == 'Crystal Mountain'][0]
crystal_polygon = shape(crystal_mountain_area['geometry'])
crystal_polygon

# %%
stac_api = "https://landsatlook.usgs.gov/stac-server"
collections =  ["landsat-c2ard-sr"] # "landsat-c2l3-fsca" will also be used for snow cover fraction
fs = fsspec.filesystem("s3", anon=False, requester_pays=True)
start_date, end_date = '1982-01-01', '2024-12-31'

# %%
client = Client.open(stac_api)
landsat_item_search = client.search(
    collections=collections,
    bbox=crystal_bounds,
    datetime=(start_date, end_date)
)

landsat_item_search.matched()
# Out:
# 2534

# %%
landsat_items = landsat_item_search.item_collection()

# %%
def process_item_parallel(args: tuple) -> Dict[str, Any]:
    """Process a single item in parallel"""
    fs, item, polygon = args
    extractor = data_classes.HLSDataExtractor(fs=fs, item=item)
    manager = data_classes.SatelliteDataManager(
        extractor=extractor
    )    
    return manager.extract_inference_data(polygon)

# %%
# %%time
# # for testing
# result = process_item_parallel((fs, landsat_items[2], crystal_polygon))

# %%
batch_size = 10
start_idx = 0
end_idx = len(landsat_items)
max_workers = 10

results = []
for i in range(start_idx, end_idx, batch_size):
    args_list = [(fs, item, crystal_polygon) for item in landsat_items[i:i+batch_size]]
    print(f"Processing items {i} to {i+batch_size} of {len(landsat_items)}")

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        future_to_item = {
            executor.submit(process_item_parallel, args): args[1] 
            for args in args_list
        }
        
        # Process completed tasks
        for future in as_completed(future_to_item):
            item = future_to_item[future]
            try:
                result = future.result()
                if result is not None:
                    results.append(result)
            except Exception as e:
                print(f"Error processing item {item.id}: {e}")
    gc.collect()
# Out:
# Processing items 0 to 10 of 2534
# Processing items 10 to 20 of 2534
# Processing items 20 to 30 of 2534
# Processing items 30 to 40 of 2534
# Processing items 40 to 50 of 2534
# Processing items 50 to 60 of 2534
# Processing items 60 to 70 of 2534
# Processing items 70 to 80 of 2534
# Processing items 80 to 90 of 2534
# Processing items 90 to 100 of 2534
# Processing items 100 to 110 of 2534
# Processing items 110 to 120 of 2534
# Processing items 120 to 130 of 2534
# Processing items 130 to 140 of 2534
# Processing items 140 to 150 of 2534
# Processing items 150 to 160 of 2534
# Processing items 160 to 170 of 2534
# Processing items 170 to 180 of 2534
# Processing items 180 to 190 of 2534
# Processing items 190 to 200 of 2534
# Processing items 200 to 210 of 2534
# Processing items 210 to 220 of 2534
# Processing items 220 to 230 of 2534
# Processing items 230 to 240 of 2534
# Processing items 240 to 250 of 2534
# Processing items 250 to 260 of 2534
# Processing items 260 to 270 of 2534
# Processing items 270 to 280 of 2534
# Processing items 280 to 290 of 2534
# Processing items 290 to 300 of 2534
# Processing items 300 to 310 of 2534
# Processing items 310 to 320 of 2534
# Processing items 320 to 330 of 2534
# Processing items 330 to 340 of 2534
# Processing items 340 to 350 of 2534
# Processing items 350 to 360 of 2534
# Processing items 360 to 370 of 2534
# Processing items 370 to 380 of 2534
# Processing items 380 to 390 of 2534
# Processing items 390 to 400 of 2534
# Processing items 400 to 410 of 2534
# Processing items 410 to 420 of 2534
# Processing items 420 to 430 of 2534
# Processing items 430 to 440 of 2534
# Processing items 440 to 450 of 2534
# Processing items 450 to 460 of 2534
# Processing items 460 to 470 of 2534
# Processing items 470 to 480 of 2534
# Processing items 480 to 490 of 2534
# Processing items 490 to 500 of 2534
# Processing items 500 to 510 of 2534
# Processing items 510 to 520 of 2534
# Processing items 520 to 530 of 2534
# Processing items 530 to 540 of 2534
# Processing items 540 to 550 of 2534
# Processing items 550 to 560 of 2534
# Processing items 560 to 570 of 2534
# Processing items 570 to 580 of 2534
# Processing items 580 to 590 of 2534
# Processing items 590 to 600 of 2534
# Processing items 600 to 610 of 2534
# Processing items 610 to 620 of 2534
# Processing items 620 to 630 of 2534
# Processing items 630 to 640 of 2534
# Processing items 640 to 650 of 2534
# Processing items 650 to 660 of 2534
# Processing items 660 to 670 of 2534
# Processing items 670 to 680 of 2534
# Processing items 680 to 690 of 2534
# Processing items 690 to 700 of 2534
# Processing items 700 to 710 of 2534
# Processing items 710 to 720 of 2534
# Processing items 720 to 730 of 2534
# Processing items 730 to 740 of 2534
# Processing items 740 to 750 of 2534
# Processing items 750 to 760 of 2534
# Processing items 760 to 770 of 2534
# Processing items 770 to 780 of 2534
# Processing items 780 to 790 of 2534
# Processing items 790 to 800 of 2534
# Processing items 800 to 810 of 2534
# Processing items 810 to 820 of 2534
# Processing items 820 to 830 of 2534
# Processing items 830 to 840 of 2534
# Processing items 840 to 850 of 2534
# Processing items 850 to 860 of 2534
# Processing items 860 to 870 of 2534
# Processing items 870 to 880 of 2534
# Processing items 880 to 890 of 2534
# Processing items 890 to 900 of 2534
# Processing items 900 to 910 of 2534
# Processing items 910 to 920 of 2534
# Processing items 920 to 930 of 2534
# Processing items 930 to 940 of 2534
# Processing items 940 to 950 of 2534
# Processing items 950 to 960 of 2534
# Processing items 960 to 970 of 2534
# Processing items 970 to 980 of 2534
# Processing items 980 to 990 of 2534
# Processing items 990 to 1000 of 2534
# Processing items 1000 to 1010 of 2534
# Processing items 1010 to 1020 of 2534
# Processing items 1020 to 1030 of 2534
# Processing items 1030 to 1040 of 2534
# Processing items 1040 to 1050 of 2534
# Processing items 1050 to 1060 of 2534
# Processing items 1060 to 1070 of 2534
# Processing items 1070 to 1080 of 2534
# Processing items 1080 to 1090 of 2534
# Processing items 1090 to 1100 of 2534
# Processing items 1100 to 1110 of 2534
# Processing items 1110 to 1120 of 2534
# Processing items 1120 to 1130 of 2534
# Processing items 1130 to 1140 of 2534
# Processing items 1140 to 1150 of 2534
# Processing items 1150 to 1160 of 2534
# Processing items 1160 to 1170 of 2534
# Processing items 1170 to 1180 of 2534
# Processing items 1180 to 1190 of 2534
# Processing items 1190 to 1200 of 2534
# Processing items 1200 to 1210 of 2534
# Processing items 1210 to 1220 of 2534
# Processing items 1220 to 1230 of 2534
# Processing items 1230 to 1240 of 2534
# Processing items 1240 to 1250 of 2534
# Processing items 1250 to 1260 of 2534
# Processing items 1260 to 1270 of 2534
# Processing items 1270 to 1280 of 2534
# Processing items 1280 to 1290 of 2534
# Processing items 1290 to 1300 of 2534
# Processing items 1300 to 1310 of 2534
# Processing items 1310 to 1320 of 2534
# Processing items 1320 to 1330 of 2534
# Processing items 1330 to 1340 of 2534
# Processing items 1340 to 1350 of 2534
# Processing items 1350 to 1360 of 2534
# Processing items 1360 to 1370 of 2534
# Processing items 1370 to 1380 of 2534
# Processing items 1380 to 1390 of 2534
# Processing items 1390 to 1400 of 2534
# Processing items 1400 to 1410 of 2534
# Processing items 1410 to 1420 of 2534
# Processing items 1420 to 1430 of 2534
# Processing items 1430 to 1440 of 2534
# Processing items 1440 to 1450 of 2534
# Processing items 1450 to 1460 of 2534
# Processing items 1460 to 1470 of 2534
# Processing items 1470 to 1480 of 2534
# Processing items 1480 to 1490 of 2534
# Processing items 1490 to 1500 of 2534
# Processing items 1500 to 1510 of 2534
# Processing items 1510 to 1520 of 2534
# Processing items 1520 to 1530 of 2534
# Processing items 1530 to 1540 of 2534
# Processing items 1540 to 1550 of 2534
# Processing items 1550 to 1560 of 2534
# Processing items 1560 to 1570 of 2534
# Processing items 1570 to 1580 of 2534
# Processing items 1580 to 1590 of 2534
# Processing items 1590 to 1600 of 2534
# Processing items 1600 to 1610 of 2534
# Processing items 1610 to 1620 of 2534
# Processing items 1620 to 1630 of 2534
# Processing items 1630 to 1640 of 2534
# Processing items 1640 to 1650 of 2534
# Processing items 1650 to 1660 of 2534
# Processing items 1660 to 1670 of 2534
# Processing items 1670 to 1680 of 2534
# Processing items 1680 to 1690 of 2534
# Processing items 1690 to 1700 of 2534
# Processing items 1700 to 1710 of 2534
# Processing items 1710 to 1720 of 2534
# Processing items 1720 to 1730 of 2534
# Processing items 1730 to 1740 of 2534
# Processing items 1740 to 1750 of 2534
# Processing items 1750 to 1760 of 2534
# Processing items 1760 to 1770 of 2534
# Processing items 1770 to 1780 of 2534
# Processing items 1780 to 1790 of 2534
# Processing items 1790 to 1800 of 2534
# Processing items 1800 to 1810 of 2534
# Processing items 1810 to 1820 of 2534
# Processing items 1820 to 1830 of 2534
# Processing items 1830 to 1840 of 2534
# Processing items 1840 to 1850 of 2534
# Processing items 1850 to 1860 of 2534
# Processing items 1860 to 1870 of 2534
# Processing items 1870 to 1880 of 2534
# Processing items 1880 to 1890 of 2534
# Processing items 1890 to 1900 of 2534
# Processing items 1900 to 1910 of 2534
# Processing items 1910 to 1920 of 2534
# Processing items 1920 to 1930 of 2534
# Processing items 1930 to 1940 of 2534
# Processing items 1940 to 1950 of 2534
# Processing items 1950 to 1960 of 2534
# Processing items 1960 to 1970 of 2534
# Processing items 1970 to 1980 of 2534
# Processing items 1980 to 1990 of 2534
# Processing items 1990 to 2000 of 2534
# Processing items 2000 to 2010 of 2534
# Processing items 2010 to 2020 of 2534
# Processing items 2020 to 2030 of 2534
# Processing items 2030 to 2040 of 2534
# Processing items 2040 to 2050 of 2534
# Processing items 2050 to 2060 of 2534
# Processing items 2060 to 2070 of 2534
# Processing items 2070 to 2080 of 2534
# Processing items 2080 to 2090 of 2534
# Processing items 2090 to 2100 of 2534
# Processing items 2100 to 2110 of 2534
# Processing items 2110 to 2120 of 2534
# Processing items 2120 to 2130 of 2534
# Processing items 2130 to 2140 of 2534
# Processing items 2140 to 2150 of 2534
# Processing items 2150 to 2160 of 2534
# Processing items 2160 to 2170 of 2534
# Processing items 2170 to 2180 of 2534
# Processing items 2180 to 2190 of 2534
# Processing items 2190 to 2200 of 2534
# Processing items 2200 to 2210 of 2534
# Processing items 2210 to 2220 of 2534
# Processing items 2220 to 2230 of 2534
# Processing items 2230 to 2240 of 2534
# Processing items 2240 to 2250 of 2534
# Processing items 2250 to 2260 of 2534
# Processing items 2260 to 2270 of 2534
# Processing items 2270 to 2280 of 2534
# Processing items 2280 to 2290 of 2534
# Processing items 2290 to 2300 of 2534
# Processing items 2300 to 2310 of 2534
# Processing items 2310 to 2320 of 2534
# Processing items 2320 to 2330 of 2534
# Processing items 2330 to 2340 of 2534
# Processing items 2340 to 2350 of 2534
# Processing items 2350 to 2360 of 2534
# Processing items 2360 to 2370 of 2534
# Processing items 2370 to 2380 of 2534
# Processing items 2380 to 2390 of 2534
# Processing items 2390 to 2400 of 2534
# Processing items 2400 to 2410 of 2534
# Processing items 2410 to 2420 of 2534
# Processing items 2420 to 2430 of 2534
# Processing items 2430 to 2440 of 2534
# Processing items 2440 to 2450 of 2534
# Processing items 2450 to 2460 of 2534
# Processing items 2460 to 2470 of 2534
# Processing items 2470 to 2480 of 2534
# Processing items 2480 to 2490 of 2534
# Processing items 2490 to 2500 of 2534
# Processing items 2500 to 2510 of 2534
# Processing items 2510 to 2520 of 2534
# Processing items 2520 to 2530 of 2534
# Processing items 2530 to 2540 of 2534

# %%
results_df = pd.concat(results)

# %%
results_df.shape
# Out:
# (20135507, 11)

# %%
#results_df.to_parquet('results.parquet')
