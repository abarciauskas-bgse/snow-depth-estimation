# %%
import json

# %%
with open('ski_areas.geojson', 'r') as f:
    ski_areas = json.load(f)
# Out:
# 66

# %%
wa_ski_sites = [area for area in ski_areas['features'] if area['properties']['location'] and area['properties']['location']['iso3166_2'] == 'US-WA']
len(wa_ski_sites)
# Out:
# 66

# %%
wa_ski_areas = [area for area in wa_ski_sites if area['geometry']['type'] != 'Point']
len(wa_ski_areas)
# Out:
# 17

# %%
with open("snotel-wa-stations.json", "r") as f:
    wa_snotel_stations = json.load(f)

wa_snotel_stations
# Out:
# [{'stationTriplet': '908:WA:SNTL',
#   'stationId': '908',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Alpine Meadows',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100100501',
#   'elevation': 3500,
#   'latitude': 47.77957,
#   'longitude': -121.69847,
#   'dataTimeZone': -8,
#   'shefId': 'APSW1',
#   'operator': 'NRCS',
#   'beginDate': '1994-09-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '990:WA:SNTL',
#   'stationId': '990',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Beaver Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100050605',
#   'elevation': 3630,
#   'latitude': 48.8793,
#   'longitude': -121.2555,
#   'dataTimeZone': -8,
#   'pedonCode': '34784',
#   'shefId': 'BVPW1',
#   'operator': 'NRCS',
#   'beginDate': '2000-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '352:WA:SNTL',
#   'stationId': '352',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Blewett Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200110501',
#   'elevation': 4240,
#   'latitude': 47.35037,
#   'longitude': -120.6796,
#   'dataTimeZone': -8,
#   'shefId': 'BPAW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1080:WA:SNTL',
#   'stationId': '1080',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Brown Top',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100050601',
#   'elevation': 5840,
#   'latitude': 48.92753,
#   'longitude': -121.19717,
#   'dataTimeZone': -8,
#   'pedonCode': '50405',
#   'shefId': 'BRTW1',
#   'operator': 'NRCS',
#   'beginDate': '2009-09-15 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1107:WA:SNTL',
#   'stationId': '1107',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Buckinghorse',
#   'dcoCode': 'OR',
#   'countyName': 'Jefferson',
#   'huc': '171100200501',
#   'elevation': 4860,
#   'latitude': 47.7086,
#   'longitude': -123.45747,
#   'dataTimeZone': -8,
#   'pedonCode': '39574',
#   'shefId': 'BKHW1',
#   'operator': 'NRCS',
#   'beginDate': '2008-06-19 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '375:WA:SNTL',
#   'stationId': '375',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Bumping Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300020105',
#   'elevation': 4600,
#   'latitude': 46.81003,
#   'longitude': -121.33058,
#   'dataTimeZone': -8,
#   'shefId': 'BMPW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '376:WA:SNTL',
#   'stationId': '376',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Bunchgrass Mdw',
#   'dcoCode': 'ID',
#   'countyName': 'Pend Oreille',
#   'huc': '170102160401',
#   'elevation': 5020,
#   'latitude': 48.68688,
#   'longitude': -117.17633,
#   'dataTimeZone': -8,
#   'shefId': 'BGMW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '942:WA:SNTL',
#   'stationId': '942',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Burnt Mountain',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100140103',
#   'elevation': 4160,
#   'latitude': 47.0444,
#   'longitude': -121.94032,
#   'dataTimeZone': -8,
#   'pedonCode': '30551',
#   'shefId': 'BUSW1',
#   'operator': 'NRCS',
#   'beginDate': '1999-07-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1109:WA:SNTL',
#   'stationId': '1109',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Calamity',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020603',
#   'elevation': 2510,
#   'latitude': 45.90362,
#   'longitude': -122.21633,
#   'dataTimeZone': -8,
#   'shefId': 'CLJW1',
#   'operator': 'NRCS',
#   'beginDate': '2008-08-21 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1085:WA:SNTL',
#   'stationId': '1085',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Cayuse Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100140301',
#   'elevation': 5260,
#   'latitude': 46.86956,
#   'longitude': -121.53434,
#   'dataTimeZone': -8,
#   'shefId': 'CAYW1',
#   'operator': 'NRCS',
#   'beginDate': '2006-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '418:WA:SNTL',
#   'stationId': '418',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Corral Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100140307',
#   'elevation': 5810,
#   'latitude': 47.01872,
#   'longitude': -121.46464,
#   'dataTimeZone': -8,
#   'shefId': 'COPW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '420:WA:SNTL',
#   'stationId': '420',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Cougar Mountain',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100130202',
#   'elevation': 3210,
#   'latitude': 47.27666,
#   'longitude': -121.67138,
#   'dataTimeZone': -8,
#   'shefId': 'CUMW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1319:WA:SNTL',
#   'stationId': '1319',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Decline Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Snohomish',
#   'huc': '171100060403',
#   'elevation': 4480,
#   'latitude': 48.23594,
#   'longitude': -121.455,
#   'dataTimeZone': -8,
#   'shefId': 'DCKW1',
#   'operator': 'NRCS',
#   'beginDate': '2018-11-21 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '943:WA:SNTL',
#   'stationId': '943',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Dungeness',
#   'dcoCode': 'OR',
#   'countyName': 'Clallam',
#   'huc': '171100200301',
#   'elevation': 3990,
#   'latitude': 47.8722,
#   'longitude': -123.07879,
#   'dataTimeZone': -8,
#   'shefId': 'DGSW1',
#   'operator': 'NRCS',
#   'beginDate': '1998-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '998:WA:SNTL',
#   'stationId': '998',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Easy Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100010101',
#   'elevation': 5280,
#   'latitude': 48.85933,
#   'longitude': -121.43895,
#   'dataTimeZone': -8,
#   'pedonCode': '39573',
#   'shefId': 'EPSW1',
#   'operator': 'NRCS',
#   'beginDate': '2008-09-19 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '910:WA:SNTL',
#   'stationId': '910',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Elbow Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100040401',
#   'elevation': 3050,
#   'latitude': 48.69092,
#   'longitude': -121.90893,
#   'dataTimeZone': -8,
#   'shefId': 'ELSW1',
#   'operator': 'NRCS',
#   'beginDate': '1995-08-24 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '478:WA:SNTL',
#   'stationId': '478',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Fish Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Kittitas',
#   'huc': '170300010102',
#   'elevation': 3430,
#   'latitude': 47.53565,
#   'longitude': -121.08553,
#   'dataTimeZone': -8,
#   'shefId': 'FISW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1159:WA:SNTL',
#   'stationId': '1159',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Gold Axe Camp',
#   'dcoCode': 'OR',
#   'countyName': 'Okanogan',
#   'huc': '170200021204',
#   'elevation': 5380,
#   'latitude': 48.9516,
#   'longitude': -118.9864,
#   'dataTimeZone': -8,
#   'shefId': 'GAXW1',
#   'operator': 'NRCS',
#   'beginDate': '2010-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1256:WA:SNTL',
#   'stationId': '1256',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Gold Mountain',
#   'dcoCode': 'OR',
#   'countyName': 'Ferry',
#   'huc': '170200011703',
#   'elevation': 4500,
#   'latitude': 48.19253,
#   'longitude': -118.45715,
#   'dataTimeZone': -8,
#   'shefId': 'GLDW1',
#   'operator': 'NRCS',
#   'beginDate': '2010-10-08 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '502:WA:SNTL',
#   'stationId': '502',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Green Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300030101',
#   'elevation': 5930,
#   'latitude': 46.54741,
#   'longitude': -121.17093,
#   'dataTimeZone': -8,
#   'pedonCode': '18458',
#   'shefId': 'GRLW1',
#   'operator': 'NRCS',
#   'beginDate': '1981-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '507:WA:SNTL',
#   'stationId': '507',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Grouse Camp',
#   'dcoCode': 'OR',
#   'countyName': 'Kittitas',
#   'huc': '170300010401',
#   'elevation': 5390,
#   'latitude': 47.28107,
#   'longitude': -120.48771,
#   'dataTimeZone': -8,
#   'pedonCode': '32032',
#   'shefId': 'GRCW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '515:WA:SNTL',
#   'stationId': '515',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Harts Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Okanogan',
#   'huc': '171100050501',
#   'elevation': 6490,
#   'latitude': 48.72047,
#   'longitude': -120.6586,
#   'dataTimeZone': -8,
#   'pedonCode': '30552',
#   'shefId': 'HRPW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '991:WA:SNTL',
#   'stationId': '991',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Hozomeen Camp',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100050602',
#   'elevation': 1680,
#   'latitude': 48.98075,
#   'longitude': -121.07976,
#   'dataTimeZone': -8,
#   'shefId': 'HZOW1',
#   'operator': 'NRCS',
#   'beginDate': '2000-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '928:WA:SNTL',
#   'stationId': '928',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Huckleberry Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100140307',
#   'elevation': 2250,
#   'latitude': 47.06565,
#   'longitude': -121.58778,
#   'dataTimeZone': -8,
#   'shefId': 'HKSW1',
#   'operator': 'NRCS',
#   'beginDate': '1997-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1129:WA:SNTL',
#   'stationId': '1129',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Indian Rock',
#   'dcoCode': 'OR',
#   'countyName': 'Klickitat',
#   'huc': '170701060301',
#   'elevation': 5310,
#   'latitude': 45.99077,
#   'longitude': -120.80768,
#   'dataTimeZone': -8,
#   'pedonCode': '50404',
#   'shefId': 'IRKW1',
#   'operator': 'NRCS',
#   'beginDate': '2008-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '553:WA:SNTL',
#   'stationId': '553',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'June Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020304',
#   'elevation': 3440,
#   'latitude': 46.14778,
#   'longitude': -122.15413,
#   'dataTimeZone': -8,
#   'shefId': 'MRBW1',
#   'operator': 'NRCS',
#   'beginDate': '1980-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '591:WA:SNTL',
#   'stationId': '591',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Lone Pine',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020203',
#   'elevation': 3940,
#   'latitude': 46.27143,
#   'longitude': -121.96288,
#   'dataTimeZone': -8,
#   'shefId': 'LPSW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '599:WA:SNTL',
#   'stationId': '599',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Lost Horse',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300030302',
#   'elevation': 5100,
#   'latitude': 46.35754,
#   'longitude': -121.0809,
#   'dataTimeZone': -8,
#   'pedonCode': '32033',
#   'shefId': 'LOHW1',
#   'operator': 'NRCS',
#   'beginDate': '1989-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '606:WA:SNTL',
#   'stationId': '606',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Lyman Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200090203',
#   'elevation': 5990,
#   'latitude': 48.19798,
#   'longitude': -120.91678,
#   'dataTimeZone': -8,
#   'shefId': 'LYLW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1069:WA:SNTL',
#   'stationId': '1069',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Lynn Lake',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100130203',
#   'elevation': 3910,
#   'latitude': 47.20172,
#   'longitude': -121.77972,
#   'dataTimeZone': -8,
#   'shefId': 'LAKW1',
#   'operator': 'NRCS',
#   'beginDate': '2007-08-30 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '999:WA:SNTL',
#   'stationId': '999',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Marten Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100051004',
#   'elevation': 3520,
#   'latitude': 48.76292,
#   'longitude': -121.69823,
#   'dataTimeZone': -8,
#   'pedonCode': '66076',
#   'shefId': 'MRTW1',
#   'operator': 'NRCS',
#   'beginDate': '2006-07-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '897:WA:SNTL',
#   'stationId': '897',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Meadows Pass',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100120101',
#   'elevation': 3230,
#   'latitude': 47.28312,
#   'longitude': -121.47197,
#   'dataTimeZone': -8,
#   'shefId': 'MPSW1',
#   'operator': 'NRCS',
#   'beginDate': '1993-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1011:WA:SNTL',
#   'stationId': '1011',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'MF Nooksack',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100040303',
#   'elevation': 4940,
#   'latitude': 48.82441,
#   'longitude': -121.92947,
#   'dataTimeZone': -8,
#   'pedonCode': '66077',
#   'shefId': 'MNOW1',
#   'operator': 'NRCS',
#   'beginDate': '2002-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '642:WA:SNTL',
#   'stationId': '642',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Morse Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300020106',
#   'elevation': 5400,
#   'latitude': 46.90585,
#   'longitude': -121.4827,
#   'dataTimeZone': -8,
#   'shefId': 'MRSW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '644:WA:SNTL',
#   'stationId': '644',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Moses Mtn',
#   'dcoCode': 'OR',
#   'countyName': 'Okanogan',
#   'huc': '170200061903',
#   'elevation': 5470,
#   'latitude': 48.36166,
#   'longitude': -119.08158,
#   'dataTimeZone': -8,
#   'pedonCode': '59488',
#   'shefId': 'MMSW1',
#   'operator': 'NRCS',
#   'beginDate': '1991-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '648:WA:SNTL',
#   'stationId': '648',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Mount Crag',
#   'dcoCode': 'OR',
#   'countyName': 'Jefferson',
#   'huc': '171100180601',
#   'elevation': 3960,
#   'latitude': 47.7637,
#   'longitude': -123.026,
#   'dataTimeZone': -8,
#   'shefId': 'MTCW1',
#   'operator': 'NRCS',
#   'beginDate': '1989-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '898:WA:SNTL',
#   'stationId': '898',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Mount Gardner',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100120103',
#   'elevation': 2930,
#   'latitude': 47.35768,
#   'longitude': -121.56812,
#   'dataTimeZone': -8,
#   'shefId': 'MGSW1',
#   'operator': 'NRCS',
#   'beginDate': '1993-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '941:WA:SNTL',
#   'stationId': '941',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Mowich',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100140105',
#   'elevation': 3170,
#   'latitude': 46.92833,
#   'longitude': -121.95232,
#   'dataTimeZone': -8,
#   'shefId': 'MHSW1',
#   'operator': 'NRCS',
#   'beginDate': '1998-09-30 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1126:WA:SNTL',
#   'stationId': '1126',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Mt. Tebo',
#   'dcoCode': 'OR',
#   'countyName': 'Mason',
#   'huc': '171100170101',
#   'elevation': 3370,
#   'latitude': 47.46061,
#   'longitude': -123.41219,
#   'dataTimeZone': -8,
#   'shefId': 'TEBW1',
#   'operator': 'NRCS',
#   'beginDate': '2020-07-08 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1259:WA:SNTL',
#   'stationId': '1259',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Muckamuck',
#   'dcoCode': 'OR',
#   'countyName': 'Okanogan',
#   'huc': '170200062001',
#   'elevation': 4470,
#   'latitude': 48.58526,
#   'longitude': -119.86624,
#   'dataTimeZone': -8,
#   'shefId': 'MUKW1',
#   'operator': 'NRCS',
#   'beginDate': '2014-06-10 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '672:WA:SNTL',
#   'stationId': '672',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Olallie Meadows',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100100301',
#   'elevation': 4010,
#   'latitude': 47.37406,
#   'longitude': -121.44213,
#   'dataTimeZone': -8,
#   'shefId': 'OMWW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '679:WA:SNTL',
#   'stationId': '679',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Paradise',
#   'dcoCode': 'OR',
#   'countyName': 'Pierce',
#   'huc': '171100150104',
#   'elevation': 5150,
#   'latitude': 46.78266,
#   'longitude': -121.74767,
#   'dataTimeZone': -8,
#   'shefId': 'AFSW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '681:WA:SNTL',
#   'stationId': '681',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Park Creek Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200090106',
#   'elevation': 4610,
#   'latitude': 48.44488,
#   'longitude': -120.91551,
#   'dataTimeZone': -8,
#   'shefId': 'PCRW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1104:WA:SNTL',
#   'stationId': '1104',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Pepper Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020111',
#   'elevation': 2140,
#   'latitude': 46.10242,
#   'longitude': -121.95555,
#   'dataTimeZone': -8,
#   'shefId': 'PPCW1',
#   'operator': 'NRCS',
#   'beginDate': '2007-08-15 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '692:WA:SNTL',
#   'stationId': '692',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Pigtail Peak',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300020301',
#   'elevation': 5800,
#   'latitude': 46.62153,
#   'longitude': -121.38643,
#   'dataTimeZone': -8,
#   'shefId': 'PGPW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1263:WA:SNTL',
#   'stationId': '1263',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Pinto Rock',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800040405',
#   'elevation': 4450,
#   'latitude': 46.32318,
#   'longitude': -121.94219,
#   'dataTimeZone': -8,
#   'shefId': 'PINW1',
#   'operator': 'NRCS',
#   'beginDate': '2014-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '699:WA:SNTL',
#   'stationId': '699',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Pope Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200100204',
#   'elevation': 3600,
#   'latitude': 47.9909,
#   'longitude': -120.56622,
#   'dataTimeZone': -8,
#   'shefId': 'PPRW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '702:WA:SNTL',
#   'stationId': '702',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Potato Hill',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170800040303',
#   'elevation': 4480,
#   'latitude': 46.3497,
#   'longitude': -121.51415,
#   'dataTimeZone': -8,
#   'shefId': 'PTHW1',
#   'operator': 'NRCS',
#   'beginDate': '1980-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '707:WA:SNTL',
#   'stationId': '707',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Quartz Peak',
#   'dcoCode': 'ID',
#   'countyName': 'Spokane',
#   'huc': '170103080302',
#   'elevation': 4710,
#   'latitude': 47.87927,
#   'longitude': -117.08938,
#   'dataTimeZone': -8,
#   'pedonCode': '30396',
#   'shefId': 'QUPW1',
#   'operator': 'NRCS',
#   'beginDate': '1985-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '711:WA:SNTL',
#   'stationId': '711',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Rainy Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '171100050503',
#   'elevation': 4880,
#   'latitude': 48.51865,
#   'longitude': -120.7358,
#   'dataTimeZone': -8,
#   'pedonCode': '34785',
#   'shefId': 'RAIW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '911:WA:SNTL',
#   'stationId': '911',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Rex River',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100120102',
#   'elevation': 3810,
#   'latitude': 47.30218,
#   'longitude': -121.60475,
#   'dataTimeZone': -8,
#   'shefId': 'RXSW1',
#   'operator': 'NRCS',
#   'beginDate': '1995-08-28 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '728:WA:SNTL',
#   'stationId': '728',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Salmon Meadows',
#   'dcoCode': 'OR',
#   'countyName': 'Okanogan',
#   'huc': '170200062003',
#   'elevation': 4460,
#   'latitude': 48.65518,
#   'longitude': -119.8383,
#   'dataTimeZone': -8,
#   'pedonCode': '59487',
#   'shefId': 'SAMW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '734:WA:SNTL',
#   'stationId': '734',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Sasse Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'Kittitas',
#   'huc': '170300010104',
#   'elevation': 4340,
#   'latitude': 47.38485,
#   'longitude': -121.06323,
#   'dataTimeZone': -8,
#   'pedonCode': '30394',
#   'shefId': 'SASW1',
#   'operator': 'NRCS',
#   'beginDate': '1983-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1231:WA:SNTL',
#   'stationId': '1231',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Satus Pass',
#   'dcoCode': 'OR',
#   'countyName': 'Klickitat',
#   'huc': '170701060301',
#   'elevation': 3960,
#   'latitude': 45.98797,
#   'longitude': -120.67734,
#   'dataTimeZone': -8,
#   'shefId': 'SPSW1',
#   'operator': 'NRCS',
#   'beginDate': '2012-08-23 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1068:WA:SNTL',
#   'stationId': '1068',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Sawmill Ridge',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100130104',
#   'elevation': 4640,
#   'latitude': 47.15992,
#   'longitude': -121.42172,
#   'dataTimeZone': -8,
#   'shefId': 'SAWW1',
#   'operator': 'NRCS',
#   'beginDate': '2006-07-27 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1043:WA:SNTL',
#   'stationId': '1043',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Sentinel Butte',
#   'dcoCode': 'OR',
#   'countyName': 'Ferry',
#   'huc': '170200021705',
#   'elevation': 4680,
#   'latitude': 48.86133,
#   'longitude': -118.39843,
#   'dataTimeZone': -8,
#   'pedonCode': '32034',
#   'shefId': 'SENW1',
#   'operator': 'NRCS',
#   'beginDate': '2003-08-27 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '748:WA:SNTL',
#   'stationId': '748',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Sheep Canyon',
#   'dcoCode': 'OR',
#   'countyName': 'Cowlitz',
#   'huc': '170800050601',
#   'elevation': 3990,
#   'latitude': 46.19325,
#   'longitude': -122.25393,
#   'dataTimeZone': -8,
#   'shefId': 'SHPW1',
#   'operator': 'NRCS',
#   'beginDate': '1980-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1257:WA:SNTL',
#   'stationId': '1257',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Skate Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Lewis',
#   'huc': '170800040505',
#   'elevation': 3770,
#   'latitude': 46.64336,
#   'longitude': -121.83044,
#   'dataTimeZone': -8,
#   'shefId': 'SKTW1',
#   'operator': 'NRCS',
#   'beginDate': '2014-10-15 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '912:WA:SNTL',
#   'stationId': '912',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Skookum Creek',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100100503',
#   'elevation': 3310,
#   'latitude': 47.68433,
#   'longitude': -121.61007,
#   'dataTimeZone': -8,
#   'shefId': 'KUSW1',
#   'operator': 'NRCS',
#   'beginDate': '1995-08-28 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '985:WA:SNTL',
#   'stationId': '985',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Sourdough Gulch',
#   'dcoCode': 'OR',
#   'countyName': 'Asotin',
#   'huc': '170601030202',
#   'elevation': 3970,
#   'latitude': 46.23713,
#   'longitude': -117.39435,
#   'dataTimeZone': -8,
#   'pedonCode': '32030',
#   'shefId': 'SGUW1',
#   'operator': 'NRCS',
#   'beginDate': '2000-07-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '776:WA:SNTL',
#   'stationId': '776',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Spencer Meadow',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020108',
#   'elevation': 3400,
#   'latitude': 46.1795,
#   'longitude': -121.92661,
#   'dataTimeZone': -8,
#   'shefId': 'SPMW1',
#   'operator': 'NRCS',
#   'beginDate': '1980-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '777:WA:SNTL',
#   'stationId': '777',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Spirit Lake',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800050502',
#   'elevation': 3520,
#   'latitude': 46.26113,
#   'longitude': -122.1772,
#   'dataTimeZone': -8,
#   'shefId': 'SPTW1',
#   'operator': 'NRCS',
#   'beginDate': '1983-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '984:WA:SNTL',
#   'stationId': '984',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Spruce Springs',
#   'dcoCode': 'OR',
#   'countyName': 'Garfield',
#   'huc': '170601030201',
#   'elevation': 5690,
#   'latitude': 46.18287,
#   'longitude': -117.54155,
#   'dataTimeZone': -8,
#   'shefId': 'SPGW1',
#   'operator': 'NRCS',
#   'beginDate': '2000-07-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '788:WA:SNTL',
#   'stationId': '788',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Stampede Pass',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100130103',
#   'elevation': 3850,
#   'latitude': 47.27427,
#   'longitude': -121.34162,
#   'dataTimeZone': -8,
#   'shefId': 'SMPW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '791:WA:SNTL',
#   'stationId': '791',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Stevens Pass',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100090102',
#   'elevation': 3940,
#   'latitude': 47.74607,
#   'longitude': -121.09288,
#   'dataTimeZone': -8,
#   'shefId': 'SVNW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '804:WA:SNTL',
#   'stationId': '804',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Surprise Lakes',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020107',
#   'elevation': 4280,
#   'latitude': 46.09497,
#   'longitude': -121.76345,
#   'dataTimeZone': -8,
#   'shefId': 'SPLW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '975:WA:SNTL',
#   'stationId': '975',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Swamp Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Skagit',
#   'huc': '171100050503',
#   'elevation': 3930,
#   'latitude': 48.57142,
#   'longitude': -120.78267,
#   'dataTimeZone': -8,
#   'shefId': 'SWSW1',
#   'operator': 'NRCS',
#   'beginDate': '1999-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1012:WA:SNTL',
#   'stationId': '1012',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Swift Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Skamania',
#   'huc': '170800020304',
#   'elevation': 4440,
#   'latitude': 46.1638,
#   'longitude': -122.18402,
#   'dataTimeZone': -8,
#   'shefId': 'SWCW1',
#   'operator': 'NRCS',
#   'beginDate': '2001-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '817:WA:SNTL',
#   'stationId': '817',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Thunder Basin',
#   'dcoCode': 'OR',
#   'countyName': 'Skagit',
#   'huc': '171100050702',
#   'elevation': 4310,
#   'latitude': 48.52753,
#   'longitude': -120.9895,
#   'dataTimeZone': -8,
#   'pedonCode': '34792',
#   'shefId': 'THBW1',
#   'operator': 'NRCS',
#   'beginDate': '1987-09-30 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '899:WA:SNTL',
#   'stationId': '899',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Tinkham Creek',
#   'dcoCode': 'OR',
#   'countyName': 'King',
#   'huc': '171100120101',
#   'elevation': 3000,
#   'latitude': 47.33198,
#   'longitude': -121.46975,
#   'dataTimeZone': -8,
#   'shefId': 'TKSW1',
#   'operator': 'NRCS',
#   'beginDate': '1993-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '824:WA:SNTL',
#   'stationId': '824',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Touchet',
#   'dcoCode': 'OR',
#   'countyName': 'Columbia',
#   'huc': '170701020303',
#   'elevation': 5520,
#   'latitude': 46.11868,
#   'longitude': -117.8505,
#   'dataTimeZone': -8,
#   'pedonCode': '30395',
#   'shefId': 'TOHW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '1171:WA:SNTL',
#   'stationId': '1171',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Trinity',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200110302',
#   'elevation': 2900,
#   'latitude': 48.07471,
#   'longitude': -120.84989,
#   'dataTimeZone': -8,
#   'shefId': 'TRIW1',
#   'operator': 'NRCS',
#   'beginDate': '2010-08-18 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '832:WA:SNTL',
#   'stationId': '832',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Trough',
#   'dcoCode': 'OR',
#   'countyName': 'Kittitas',
#   'huc': '170200100402',
#   'elevation': 5480,
#   'latitude': 47.23328,
#   'longitude': -120.29412,
#   'dataTimeZone': -8,
#   'pedonCode': '32031',
#   'shefId': 'TRGW1',
#   'operator': 'NRCS',
#   'beginDate': '1978-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '841:WA:SNTL',
#   'stationId': '841',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Upper Wheeler',
#   'dcoCode': 'OR',
#   'countyName': 'Chelan',
#   'huc': '170200100310',
#   'elevation': 4330,
#   'latitude': 47.28734,
#   'longitude': -120.37015,
#   'dataTimeZone': -8,
#   'shefId': 'UPWW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '974:WA:SNTL',
#   'stationId': '974',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Waterhole',
#   'dcoCode': 'OR',
#   'countyName': 'Clallam',
#   'huc': '171100200506',
#   'elevation': 5010,
#   'latitude': 47.94485,
#   'longitude': -123.42594,
#   'dataTimeZone': -8,
#   'shefId': 'WHSW1',
#   'operator': 'NRCS',
#   'beginDate': '1999-09-30 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '909:WA:SNTL',
#   'stationId': '909',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'Wells Creek',
#   'dcoCode': 'OR',
#   'countyName': 'Whatcom',
#   'huc': '171100040103',
#   'elevation': 4030,
#   'latitude': 48.8661,
#   'longitude': -121.78976,
#   'dataTimeZone': -8,
#   'shefId': 'WCSW1',
#   'operator': 'NRCS',
#   'beginDate': '1995-08-24 00:00',
#   'endDate': '2100-01-01 00:00'},
#  {'stationTriplet': '863:WA:SNTL',
#   'stationId': '863',
#   'stateCode': 'WA',
#   'networkCode': 'SNTL',
#   'name': 'White Pass E.S.',
#   'dcoCode': 'OR',
#   'countyName': 'Yakima',
#   'huc': '170300020301',
#   'elevation': 4440,
#   'latitude': 46.64142,
#   'longitude': -121.38153,
#   'dataTimeZone': -8,
#   'shefId': 'WHPW1',
#   'operator': 'NRCS',
#   'beginDate': '1979-10-01 00:00',
#   'endDate': '2100-01-01 00:00'}]

# %%
min_lat, min_lon, max_lat, max_lon = [45, -124, 49, -116]

import folium

m = folium.Map(location=[(max_lat - min_lat)/2 + min_lat, (max_lon - min_lon)/2 + min_lon], zoom_start=7)

wa_ski_geojson = {
    'type': 'FeatureCollection',
    'features': wa_ski_areas
}

folium.GeoJson(
    data=wa_ski_geojson,
    popup=folium.GeoJsonPopup(fields=['name'])
).add_to(m)

for snotel_station in wa_snotel_stations:
    
    folium.CircleMarker(
        location=[snotel_station['latitude'], snotel_station['longitude']],
        popup=f"{snotel_station['name']} ({snotel_station['stationTriplet']})",
        radius=3,
        color='green',
        fill=True,
        fillOpacity=0.7
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26dbdf69c9826382908a099ba8e0ca70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26dbdf69c9826382908a099ba8e0ca70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26dbdf69c9826382908a099ba8e0ca70 = L.map(
#                 &quot;map_26dbdf69c9826382908a099ba8e0ca70&quot;,
#                 {
#                     center: [47.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d3ee2492121998f9e28f239e42a0999 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d3ee2492121998f9e28f239e42a0999.addTo(map_26dbdf69c9826382908a099ba8e0ca70);
#
#
#
#         function geo_json_8bafd47a4d2dce5033e8b415afe82978_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8bafd47a4d2dce5033e8b415afe82978 = L.geoJson(null, {
#                 onEachFeature: geo_json_8bafd47a4d2dce5033e8b415afe82978_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_8bafd47a4d2dce5033e8b415afe82978_add (data) {
#             geo_json_8bafd47a4d2dce5033e8b415afe82978
#                 .addData(data);
#         }
#             geo_json_8bafd47a4d2dce5033e8b415afe82978_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-121.3873349, 46.639049], [-121.3936423, 46.638504900000015], [-121.3993058, 46.63428739999999], [-121.40250900000002, 46.62830070000002], [-121.3998877, 46.62476520000001], [-121.40710530000003, 46.6192936], [-121.41046980000003, 46.6161447], [-121.41952820000003, 46.61693860000001], [-121.4201461, 46.6142489], [-121.41476060000004, 46.6047673], [-121.4049858, 46.6041547], [-121.3956402, 46.6152934], [-121.37975609999997, 46.62322070000001], [-121.37391099999998, 46.6296954], [-121.37579329999997, 46.631827], [-121.3808624, 46.6319518], [-121.3816714, 46.63749590000001], [-121.3873349, 46.639049]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;activities&quot;: [&quot;downhill&quot;, &quot;nordic&quot;], &quot;id&quot;: &quot;1798662f2e3fe07cc31989a26a3dad9ba4214c74&quot;, &quot;location&quot;: {&quot;iso3166_1Alpha2&quot;: &quot;US&quot;, &quot;iso3166_2&quot;: &quot;US-WA&quot;, &quot;localized&quot;: {&quot;en&quot;: {&quot;country&quot;: &quot;United States&quot;, &quot;locality&quot;: null, &quot;region&quot;: &quot;Washington&quot;}}}, &quot;name&quot;: &quot;White Pass Ski Area&quot;, &quot;runConvention&quot;: &quot;north_america&quot;, &quot;sources&quot;: [{&quot;id&quot;: &quot;way/1254864194&quot;, &quot;type&quot;: &quot;openstreetmap&quot;}, {&quot;id&quot;: 184, &quot;type&quot;: &quot;skimap.org&quot;}], &quot;statistics&quot;: {&quot;lifts&quot;: {&quot;byType&quot;: {&quot;chair_lift&quot;: {&quot;combinedElevationChange&quot;: 1284, &quot;count&quot;: 5, &quot;lengthInKm&quot;: 5.262391931746411, &quot;maxElevation&quot;: 1980, &quot;minElevation&quot;: 1366}, &quot;magic_carpet&quot;: {&quot;combinedElevationChange&quot;: 12, &quot;count&quot;: 2, &quot;lengthInKm&quot;: 0.08970014906576797, &quot;maxElevation&quot;: 1374, &quot;minElevation&quot;: 1367}, &quot;platter&quot;: {&quot;combinedElevationChange&quot;: 13, &quot;count&quot;: 1, &quot;lengthInKm&quot;: 0.11253988691797753, &quot;maxElevation&quot;: 1381, &quot;minElevation&quot;: 1368}}, &quot;maxElevation&quot;: 1980, &quot;minElevation&quot;: 1366}, &quot;maxElevation&quot;: 1980, &quot;minElevation&quot;: 1366, &quot;runs&quot;: {&quot;byActivity&quot;: {&quot;downhill&quot;: {&quot;byDifficulty&quot;: {&quot;advanced&quot;: {&quot;combinedElevationChange&quot;: 1073, &quot;count&quot;: 11, &quot;lengthInKm&quot;: 4.1853301958893265, &quot;maxElevation&quot;: 1818, &quot;minElevation&quot;: 1428}, &quot;easy&quot;: {&quot;combinedElevationChange&quot;: 1347, &quot;count&quot;: 9, &quot;lengthInKm&quot;: 10.420578841975516, &quot;maxElevation&quot;: 1980, &quot;minElevation&quot;: 1368}, &quot;intermediate&quot;: {&quot;combinedElev
